# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
accel = pd.read_csv('acc.csv', header=None)
accel.columns = ['time','ax','ay','az']
gyro = pd.read_csv('gyro.csv', header=None)
gyro.columns = ['time','gx','gy','gz']
mag = pd.read_csv('mag.csv', header=None)
mag.columns = ['time','mx','my','mz']
true_data = pd.read_csv('true.csv', header=None)
true_data.columns = ['time','roll','pitch','yaw']

# %%
# x for nn is acc, gyro, mag
# y for nn is true_data
x = pd.concat([accel[['ax','ay','az']], gyro[['gx','gy','gz']], mag[['mx','my','mz']]], axis=1)
y = true_data[['roll','pitch','yaw']]
# add noise to x
noise = np.random.normal(0, 0.1, x.shape)
x += noise

# %%
# plot data
plt.figure(1)
plt.subplot(311)
plt.plot(x['ax'], label='ax')
plt.plot(x['ay'], label='ay')
plt.plot(x['az'], label='az')
plt.legend()
plt.subplot(312)    
plt.plot(x['gx'], label='gx')
plt.plot(x['gy'], label='gy')
plt.plot(x['gz'], label='gz')
plt.legend()
plt.subplot(313)
plt.plot(x['mx'], label='mx')
plt.plot(x['my'], label='my')
plt.plot(x['mz'], label='mz')
plt.legend()
plt.show()

# %%
# measure data
roll_measure = np.zeros(len(x))
pitch_measure = np.zeros(len(x))
yaw_measure = np.zeros(len(x))

# calculate roll, pitch, yaw
for i in range(len(x)):
    ax = x['ax'][i]
    ay = x['ay'][i]
    az = x['az'][i]
    mx = x['mx'][i]
    my = x['my'][i]
    mz = x['mz'][i]
    roll_measure[i] = np.arctan2(-ay, -az)
    pitch_measure[i] = np.arcsin(ax/9.8)
    yaw_measure[i] = np.arctan2(-np.cos(roll_measure[i])*my + np.sin(roll_measure[i])*mz, np.cos(pitch_measure[i])*mx + np.sin(pitch_measure[i])*np.sin(roll_measure[i])*my + np.sin(pitch_measure[i])*np.cos(roll_measure[i])*mz)-4.0266*np.pi/180
# plot data vs measure
plt.figure(2)
plt.plot(roll_measure, label='roll_measure')
plt.plot(y['roll'], label='roll')
plt.legend()
plt.show()

# %%
# propagation data
roll_prop = np.zeros(len(x))
pitch_prop = np.zeros(len(x))
yaw_prop = np.zeros(len(x))
roll_prop[0] = 0
pitch_prop[0] = 0
yaw_prop[0] = 0
for i in range(1, len(x)):
    dt = accel['time'][i] - accel['time'][i-1]
    roll_prop[i] = roll_prop[i-1] + dt*(gyro['gx'][i] + np.sin(roll_prop[i-1])*np.tan(pitch_prop[i-1])*gyro['gy'][i] + np.cos(roll_prop[i-1])*np.tan(pitch_prop[i-1])*gyro['gz'][i])
    pitch_prop[i] = pitch_prop[i-1] + dt*(np.cos(roll_prop[i-1])*gyro['gy'][i] - np.sin(roll_prop[i-1])*gyro['gz'][i])
    yaw_prop[i] = yaw_prop[i-1] + dt*(np.sin(roll_prop[i-1])/np.cos(pitch_prop[i-1])*gyro['gy'][i] + np.cos(roll_prop[i-1])/np.cos(pitch_prop[i-1])*gyro['gz'][i])
# plot data vs propagation
plt.figure(3)
plt.plot(y['roll'], label='roll')
plt.plot(roll_prop, label='roll_prop')
plt.legend()
plt.show()

# %%
# x ---> measurement + propagation
# y ---> true_data
x = pd.concat([pd.DataFrame([roll_measure, pitch_measure, yaw_measure]).T, pd.DataFrame([roll_prop, pitch_prop, yaw_prop]).T], axis=1)
y = true_data[['roll','pitch','yaw']]
print(y)
# prepare data for nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# build nn
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(32, input_shape=(6,), activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(3))
model.compile(optimizer=Adam(lr=0.001), loss='mse')
model.summary()
# Out:
#           roll     pitch       yaw
# 0     0.000175  0.000262  0.014045
# 1     0.000349  0.000524  0.014394
# 2     0.000524  0.000785  0.014743
# 3     0.000698  0.001047  0.015091
# 4     0.000872  0.001308  0.015439
# ...        ...       ...       ...
# 4995 -0.005249 -0.007721  0.003684
# 4996 -0.005082 -0.007485  0.003972
# 4997 -0.004915 -0.007248  0.004264
# 4998 -0.004747 -0.007009  0.004559
# 4999 -0.004579 -0.006768  0.004858
#
# [5000 rows x 3 columns]
# 2024-01-02 12:50:12.595858: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                224
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 1379 (5.39 KB)
# Trainable params: 1379 (5.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# train nn
history = model.fit(x, y, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 1s 3ms/step - loss: 3.5427e-05 - val_loss: 1.5530e-06
# Epoch 2/100
# 125/125 [==============================] - 0s 2ms/step - loss: 3.1008e-07 - val_loss: 1.5102e-06
# Epoch 3/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.7994e-07 - val_loss: 1.7609e-06
# Epoch 4/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.9359e-07 - val_loss: 9.5727e-07
# Epoch 5/100
# 125/125 [==============================] - 0s 2ms/step - loss: 3.3143e-07 - val_loss: 9.1788e-07
# Epoch 6/100
# 125/125 [==============================] - 0s 2ms/step - loss: 3.0120e-07 - val_loss: 1.0488e-06
# Epoch 7/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.8676e-07 - val_loss: 8.7802e-07
# Epoch 8/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.7943e-07 - val_loss: 1.1465e-06
# Epoch 9/100
# 125/125 [==============================] - 0s 2ms/step - loss: 3.3218e-07 - val_loss: 4.0638e-07
# Epoch 10/100
# 125/125 [==============================] - 0s 2ms/step - loss: 3.0495e-07 - val_loss: 2.4221e-06
# Epoch 11/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.8157e-07 - val_loss: 6.9981e-07
# Epoch 12/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.3872e-07 - val_loss: 1.2795e-06
# Epoch 13/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.2393e-07 - val_loss: 6.9944e-07
# Epoch 14/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.9998e-07 - val_loss: 6.2116e-07
# Epoch 15/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.2180e-07 - val_loss: 1.1790e-06
# Epoch 16/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.2444e-07 - val_loss: 1.1865e-06
# Epoch 17/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.8259e-07 - val_loss: 4.6503e-07
# Epoch 18/100
# 125/125 [==============================] - 0s 4ms/step - loss: 1.5471e-07 - val_loss: 7.1869e-07
# Epoch 19/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.6824e-07 - val_loss: 4.7027e-07
# Epoch 20/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.6383e-07 - val_loss: 2.6617e-07
# Epoch 21/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.2656e-07 - val_loss: 5.1974e-08
# Epoch 22/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.8942e-07 - val_loss: 1.3140e-06
# Epoch 23/100
# 125/125 [==============================] - 0s 3ms/step - loss: 2.0343e-07 - val_loss: 4.1344e-07
# Epoch 24/100
# 125/125 [==============================] - 0s 3ms/step - loss: 1.7684e-07 - val_loss: 7.3643e-07
# Epoch 25/100
# 125/125 [==============================] - 0s 3ms/step - loss: 1.6215e-07 - val_loss: 6.6329e-08
# Epoch 26/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.5635e-07 - val_loss: 5.2522e-08
# Epoch 27/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.3771e-07 - val_loss: 1.2468e-07
# Epoch 28/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.3711e-07 - val_loss: 3.3424e-07
# Epoch 29/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.4811e-08 - val_loss: 3.0294e-07
# Epoch 30/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.5285e-07 - val_loss: 6.9707e-07
# Epoch 31/100
# 125/125 [==============================] - 0s 3ms/step - loss: 1.5990e-07 - val_loss: 2.7714e-08
# Epoch 32/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0135e-07 - val_loss: 3.1952e-07
# Epoch 33/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.7854e-07 - val_loss: 7.3043e-07
# Epoch 34/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.9156e-07 - val_loss: 8.3243e-08
# Epoch 35/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.7778e-08 - val_loss: 8.9288e-08
# Epoch 36/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.1233e-07 - val_loss: 2.0035e-07
# Epoch 37/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0362e-07 - val_loss: 5.7259e-07
# Epoch 38/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0936e-07 - val_loss: 1.7582e-07
# Epoch 39/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.4013e-07 - val_loss: 8.5511e-08
# Epoch 40/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.3612e-07 - val_loss: 2.0382e-07
# Epoch 41/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.3947e-07 - val_loss: 2.3906e-07
# Epoch 42/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0616e-07 - val_loss: 6.6751e-08
# Epoch 43/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.8719e-08 - val_loss: 1.0824e-07
# Epoch 44/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.6824e-07 - val_loss: 1.3767e-07
# Epoch 45/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.9999e-08 - val_loss: 3.8368e-08
# Epoch 46/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.3720e-08 - val_loss: 4.0668e-07
# Epoch 47/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.7244e-07 - val_loss: 1.3488e-07
# Epoch 48/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.0594e-08 - val_loss: 8.7222e-08
# Epoch 49/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.8950e-07 - val_loss: 1.8681e-07
# Epoch 50/100
# 125/125 [==============================] - 0s 2ms/step - loss: 2.2149e-07 - val_loss: 5.4351e-08
# Epoch 51/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.4977e-08 - val_loss: 7.4848e-08
# Epoch 52/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.9863e-08 - val_loss: 4.4272e-07
# Epoch 53/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.1125e-07 - val_loss: 1.3564e-07
# Epoch 54/100
# 125/125 [==============================] - 0s 2ms/step - loss: 5.8512e-08 - val_loss: 1.6693e-07
# Epoch 55/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.0593e-08 - val_loss: 1.3352e-07
# Epoch 56/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.9460e-08 - val_loss: 1.6063e-07
# Epoch 57/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.8633e-08 - val_loss: 3.0156e-07
# Epoch 58/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.4661e-07 - val_loss: 3.8024e-08
# Epoch 59/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.4069e-08 - val_loss: 9.1161e-08
# Epoch 60/100
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0061e-07 - val_loss: 1.4736e-07
# Epoch 61/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.3916e-07 - val_loss: 6.4274e-08
# Epoch 62/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.1960e-07 - val_loss: 2.0432e-07
# Epoch 63/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.9974e-08 - val_loss: 3.3428e-07
# Epoch 64/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.8595e-07 - val_loss: 3.7495e-08
# Epoch 65/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.5975e-08 - val_loss: 1.7361e-07
# Epoch 66/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.4744e-07 - val_loss: 1.5069e-07
# Epoch 67/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.9151e-08 - val_loss: 1.1957e-07
# Epoch 68/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0593e-07 - val_loss: 2.4371e-07
# Epoch 69/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.7659e-08 - val_loss: 7.0540e-08
# Epoch 70/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.4687e-08 - val_loss: 2.5645e-07
# Epoch 71/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.2724e-08 - val_loss: 7.1035e-07
# Epoch 72/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0171e-07 - val_loss: 5.5604e-08
# Epoch 73/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0683e-07 - val_loss: 4.5564e-08
# Epoch 74/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.9472e-08 - val_loss: 2.3335e-07
# Epoch 75/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.1717e-08 - val_loss: 3.3052e-07
# Epoch 76/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0063e-07 - val_loss: 8.8439e-08
# Epoch 77/100
# 125/125 [==============================] - 0s 2ms/step - loss: 7.9807e-08 - val_loss: 4.0901e-08
# Epoch 78/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.2803e-07 - val_loss: 2.0199e-07
# Epoch 79/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.5120e-07 - val_loss: 5.1810e-08
# Epoch 80/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.2999e-08 - val_loss: 2.3990e-08
# Epoch 81/100
# 125/125 [==============================] - 0s 2ms/step - loss: 7.9701e-08 - val_loss: 3.3999e-08
# Epoch 82/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.5730e-07 - val_loss: 2.3819e-07
# Epoch 83/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.1700e-07 - val_loss: 5.4045e-08
# Epoch 84/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.5942e-08 - val_loss: 1.2162e-07
# Epoch 85/100
# 125/125 [==============================] - 0s 3ms/step - loss: 1.0943e-07 - val_loss: 7.0040e-08
# Epoch 86/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.5956e-08 - val_loss: 1.2258e-07
# Epoch 87/100
# 125/125 [==============================] - 0s 2ms/step - loss: 7.3049e-08 - val_loss: 2.1326e-07
# Epoch 88/100
# 125/125 [==============================] - 0s 2ms/step - loss: 8.3808e-08 - val_loss: 2.1268e-07
# Epoch 89/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.1655e-07 - val_loss: 1.3456e-07
# Epoch 90/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.0106e-08 - val_loss: 1.0906e-07
# Epoch 91/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.8376e-08 - val_loss: 3.2543e-08
# Epoch 92/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.6269e-08 - val_loss: 9.0207e-08
# Epoch 93/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0135e-07 - val_loss: 7.8530e-08
# Epoch 94/100
# 125/125 [==============================] - 0s 2ms/step - loss: 6.1602e-08 - val_loss: 1.1364e-07
# Epoch 95/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.2727e-08 - val_loss: 4.7395e-08
# Epoch 96/100
# 125/125 [==============================] - 0s 2ms/step - loss: 7.6087e-08 - val_loss: 1.2702e-07
# Epoch 97/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.0311e-07 - val_loss: 1.0859e-07
# Epoch 98/100
# 125/125 [==============================] - 0s 2ms/step - loss: 1.3179e-07 - val_loss: 5.9636e-08
# Epoch 99/100
# 125/125 [==============================] - 0s 2ms/step - loss: 7.7588e-08 - val_loss: 5.3020e-08
# Epoch 100/100
# 125/125 [==============================] - 0s 2ms/step - loss: 9.5239e-08 - val_loss: 7.8499e-08

# %%
# predict
y_pred = model.predict(x)
# plot data vs predict
plt.figure(4)
plt.plot(y_pred[:,0], label='roll_pred')
plt.plot(y['roll'], label='roll')
# Out:
# 157/157 [==============================] - 1s 2ms/step

# %%
# save model
model.save('model.h5')
# Out:
# /Users/Ali/Library/Python/3.11/lib/python/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# normalize data
x_mean = x.mean()
x_std = x.std()
x = (x - x_mean) / x_std
y_mean = y.mean()
y_std = y.std()
y = (y - y_mean) / y_std

# %%
# make LSTM neuarl network
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

model = Sequential()
model.add(LSTM(64, activation='tanh', input_shape=(9, 1)))
model.add(Dense(64, activation='tanh'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 16961 (66.25 KB)
# Trainable params: 16961 (66.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# reshape x and y   
x = np.array(x)
y = np.array(y)
x = x.reshape(x.shape[0], 9, 1)
y = y.reshape(y.shape[0], 3, 1)

# %%
# fit model
model.fit(x, y, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 4s 7ms/step - loss: 0.8155
# Epoch 2/10
# 157/157 [==============================] - 1s 8ms/step - loss: 0.6759
# Epoch 3/10
# 157/157 [==============================] - 1s 8ms/step - loss: 0.6718
# Epoch 4/10
# 157/157 [==============================] - 1s 6ms/step - loss: 0.6687
# Epoch 5/10
# 157/157 [==============================] - 1s 6ms/step - loss: 0.6675
# Epoch 6/10
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6672
# Epoch 7/10
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6670
# Epoch 8/10
# 157/157 [==============================] - 1s 8ms/step - loss: 0.6670
# Epoch 9/10
# 157/157 [==============================] - 1s 9ms/step - loss: 0.6669
# Epoch 10/10
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6669

# %%
# save model
model.save('model_AI_AHRS.h5')

# %%
x_mean = np.array(x_mean)
x_std = np.array(x_std)
y_mean = np.array(y_mean)
y_std = np.array(y_std)

print(x_mean.shape)
print(x_std.shape)
print(y_mean.shape)
print(y_std.shape)
# Out:
# (9,)
# (9,)
# (3,)
# (3,)

# %%
# predict
y_pred = model.predict(x)
# denormalize
x = x.reshape(x.shape[0], 9)
x = x * x_std + x_mean
y = y.reshape(y.shape[0], 3)
y_pred = y_pred * y_std + y_mean

# plot result
plt.figure(2)
plt.subplot(311)
plt.plot(y[:,0], label='true')
plt.plot(y_pred[:,0], label='pred')
plt.legend()
plt.subplot(312)
plt.plot(y[:,1], label='true')
plt.plot(y_pred[:,1], label='pred')
plt.legend()
plt.subplot(313)
plt.plot(y[:,2], label='true')
plt.plot(y_pred[:,2], label='pred')
plt.legend()
plt.show()
# Out:
# 157/157 [==============================] - 1s 3ms/step
